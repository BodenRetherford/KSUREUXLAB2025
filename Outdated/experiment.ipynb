# %%
#IMPORT some LIBS
import pandas as pd
import seaborn as sb

#IMPORT DATASET
df = sb.load_dataset("tips")
df.head()

ez = pd.read_csv('monomers_33356242.tsv', sep='\t')
ez.head()
# Out:
#    BindingDB Reactant_set_id  \
# 0                   51455621
# 1                   51455622
# 2                   51455623
# 3                   51455624
# 4                   51455625
#
#                                        Ligand SMILES  \
# 0  CN1CCN(CC1)c1ccc(Nc2ncc3cc(C#N)c(=O)n(C4CCCC4)...
# 1  CN1c2cc3ccccc3cc2C(=O)N(C)c2cnc(Nc3cnn(c3)C3CC...
# 2  CN1c2ccccc2C(=O)N(C)c2c(C)nc(Nc3cnn(c3)C3CCNCC...
# 3  CN1c2cc3ccccc3cc2C(=O)N(C)c2c(C)nc(Nc3cnn(c3)C...
# 4  CN1CCN(CC1)C(=O)c1ccc(Nc2ncc3N(C)C(=O)c4ccccc4...
#
#                                         Ligand InChI  \
# 0  InChI=1S/C24H27N7O/c1-29-10-12-30(13-11-29)20-...
# 1  InChI=1S/C25H26N8O/c1-31-21-12-17-6-4-3-5-16(1...
# 2  InChI=1S/C22H26N8O/c1-14-19-20(28(2)18-7-5-4-6...
# 3  InChI=1S/C26H28N8O/c1-16-23-24(31-26(29-16)30-...
# 4  InChI=1S/C26H29N7O2/c1-17-15-18(9-10-19(17)25(...
#
#               Ligand InChI Key  BindingDB MonomerID  \
# 0  VADOZMZXXRBXNY-UHFFFAOYSA-N             50447512
# 1  MFWHDFGMXHATNR-UHFFFAOYSA-N             50587669
# 2  LJORJQJUACCUBV-UHFFFAOYSA-N             50587670
# 3  CHSDJDLAKKAWCI-UHFFFAOYSA-N             50587671
# 4  PHENCDSAYZNXRO-UHFFFAOYSA-N                86615
#
#                                BindingDB Ligand Name  \
# 0                                      CHEMBL3115681
# 1                                      CHEMBL5190521
# 2                                      CHEMBL5202161
# 3                                      CHEMBL4303250
# 4  Benzo[e]pyrimido[5,4-b][1,4]diazepin-6(11H)-on...
#
#                       Target Name  \
# 0  NUAK family SNF1-like kinase 1
# 1  NUAK family SNF1-like kinase 1
# 2  NUAK family SNF1-like kinase 1
# 3  NUAK family SNF1-like kinase 1
# 4  NUAK family SNF1-like kinase 1
#
#   Target Source Organism According to Curator or DataSource  Ki (nM)  \
# 0                                       Homo sapiens             NaN
# 1                                       Homo sapiens             NaN
# 2                                       Homo sapiens             NaN
# 3                                       Homo sapiens             NaN
# 4                                       Homo sapiens             NaN
#
#   IC50 (nM)  ...  UniProt (SwissProt) Recommended Name of Target Chain  \
# 0       5.0  ...                     NUAK family SNF1-like kinase 1
# 1        30  ...                     NUAK family SNF1-like kinase 1
# 2        17  ...                     NUAK family SNF1-like kinase 1
# 3       100  ...                     NUAK family SNF1-like kinase 1
# 4       6.0  ...                     NUAK family SNF1-like kinase 1
#
#    UniProt (SwissProt) Entry Name of Target Chain  \
# 0                                     NUAK1_HUMAN
# 1                                     NUAK1_HUMAN
# 2                                     NUAK1_HUMAN
# 3                                     NUAK1_HUMAN
# 4                                     NUAK1_HUMAN
#
#    UniProt (SwissProt) Primary ID of Target Chain  \
# 0                                          O60285
# 1                                          O60285
# 2                                          O60285
# 3                                          O60285
# 4                                          O60285
#
#    UniProt (SwissProt) Secondary ID(s) of Target Chain  \
# 0                                      A7MD39 Q96KA8
# 1                                      A7MD39 Q96KA8
# 2                                      A7MD39 Q96KA8
# 3                                      A7MD39 Q96KA8
# 4                                      A7MD39 Q96KA8
#
#    UniProt (SwissProt) Alternative ID(s) of Target Chain  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    UniProt (TrEMBL) Submitted Name of Target Chain  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#   UniProt (TrEMBL) Entry Name of Target Chain  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#    UniProt (TrEMBL) Primary ID of Target Chain  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#   UniProt (TrEMBL) Secondary ID(s) of Target Chain  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    UniProt (TrEMBL) Alternative ID(s) of Target Chain
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 50 columns]

# %%
#DESIGNATING FEATURES(X) and PREDICTED VAR(y)
X = df[['total_bill','tip','size']]
y = df['sex']

#SPLITTING TESTING AND TRAINING DATA (FIND OUT HOW THIS SPLIT HAPPENS)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
#BUILDING RANDOM FOREST
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
#SIMPLE MODEL SCORE, (IDK WHAT THIS IS MADE WITH)
y_pred = rf.predict(X_test)
rf.score(X_test,y_test)
# Out:
# 0.5102040816326531

# %%
#ADVANCED METRICS
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#       Female       0.33      0.20      0.25        20
#         Male       0.57      0.72      0.64        29
#
#     accuracy                           0.51        49
#    macro avg       0.45      0.46      0.44        49
# weighted avg       0.47      0.51      0.48        49

# %%
#FEATURE IMPORTANCE
features = pd.DataFrame(rf.feature_importances_, index = X.columns)
features.head()
# Out:
#                    0
# total_bill  0.539488
# tip         0.390533
# size        0.069979

# %%
#HYPER PARAMATERS (We should do hyperparameter optimization)
rf2 = RandomForestClassifier(n_estimators = 1000,
                             criterion = 'entropy',
                             min_samples_split = 10,
                             max_depth = 14,
                             random_state = 42
)
rf2.fit(X_train, y_train)
rf2.score(X_test, y_test)
# Out:
# 0.5102040816326531

# %%
y_pred2 = rf2.predict(X_test)
print(classification_report(y_test, y_pred2))
# Out:
#               precision    recall  f1-score   support
#
#       Female       0.25      0.10      0.14        20
#         Male       0.56      0.79      0.66        29
#
#     accuracy                           0.51        49
#    macro avg       0.41      0.45      0.40        49
# weighted avg       0.43      0.51      0.45        49

# %%
#NOW WE DO A REGRESSOR
#DESIGNATING FEATURES(XR) and PREDICTED VAR(yR)
XR = df[['total_bill','size']]
yR = df['tip']

#SPLITTING TESTING AND TRAINING DATA (FIND OUT HOW THIS SPLIT HAPPENS)
XR_train, XR_test, yR_train, yR_test = train_test_split(XR, yR, test_size=0.2)

# %%
#CREATING REGRESSOR MODEL
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor()
rfr.fit(XR_train, yR_train)
# Out:
# RandomForestRegressor()

# %%
#METRICS
yR_pred = rfr.predict(XR_test)
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
print(mean_absolute_error(yR_pred, yR_test))
print(mean_squared_error(yR_pred, yR_test))
print(r2_score(yR_test, yR_pred))
# Out:
# 0.7944673469387755
# 0.9694931940816331
# 0.3122508501930006

# %%
#Hyperparam tuning
param_grid = {
    'n_estimators': [100, 200, 300], #number of decision trees
    'max_depth': [10,20,30], #depth of trees
    'min_samples_split':[2,5,10], #min number of samples at split node(WHAT THIS MEAN?)
    'min_samples_leaf': [1,2,3] #min number of samples at leaf node (WHAT THIS MEAN?)
} #all numbers of options multiplied together give CV value (WAT?)

# %%
#NEW MODEL FOR HYPERPARAMATIZATION
from sklearn.model_selection import GridSearchCV
rfr_cv = GridSearchCV(estimator=rfr, param_grid=param_grid, cv = 3, scoring='neg_mean_squared_error', n_jobs = -1)
rfr_cv.fit(XR_train, yR_train)
# Out:
# GridSearchCV(cv=3, estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'max_depth': [10, 20, 30],
#                          'min_samples_leaf': [1, 2, 3],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [100, 200, 300]},
#              scoring='neg_mean_squared_error')

# %%
#METRICS FOR NEW MODEL
yR_pred = rfr_cv.predict(XR_test)
print(mean_absolute_error(yR_pred, yR_test))
print(mean_squared_error(yR_pred, yR_test))
print(r2_score(yR_test, yR_pred))
# Out:
# 0.6387212108416758
# 0.741537736596925
# 0.4739602598474769
